# %% [markdown]
# <a href="https://colab.research.google.com/github/JRKagumba/2D-video-based-running-analysis/blob/main/notebooks/01_Apply_Preprocessing_steps_to_Raw_Data_and_Save_Plots.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Mount Drive

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np
import json
import os

import matplotlib.pyplot as plt
import matplotlib.ticker as ticker 

from scipy import stats

# %% [markdown]
# ### Initialize Helper Functions

# %%
def zeros_to_nans(df):
    """If keypoint is not detected, OpenPose returns 0 for undetected keypoints"""
    df[df < 0.0001] = np.NaN
    return df

def apply_interpolation(df):
    """Fill in missing values"""
    return df.apply(lambda col: col.interpolate(), axis=0)

def remove_high_frequency_noise_with_rolling_window_function(df):
    """Apply smoothing with a Gaussian filter"""
    return df.rolling(window=5, win_type='gaussian', center=True).mean(std=5)

def cut_out_noise_at_beginning_of_clips(df):
    """
    Remove noisy signals present before individual has started to run
    """
    #2a A df with all the row-row differences
    difference_df = abs(df.apply(lambda x: x.diff(), axis=0))

    #2b A series list all columns with the index number that had the max value
    max_df = difference_df.apply(lambda x: x.idxmax(), axis=0)

    #2c slice df to remove noisy portion 
    frequency, bins = np.histogram(max_df, bins=10, range=[min(max_df), max(max_df)])
    bin_index_of_max = np.argmax(frequency)
    df_index_of_max = round(bins[bin_index_of_max+1])
    no_noise_df=df[df_index_of_max+1:].reset_index(drop=True)

    return no_noise_df


def remove_high_frequency_noise_at_single_index(df):
    """
    Removes high frequency noise at a particularly troublesome index
    """

    #2a A df with all the row-row differences
    difference_df = abs(df.apply(lambda x: x.diff(), axis=0))

    #2b A series list all columns with the index number that had the max value
    max_df = difference_df.apply(lambda x: x.idxmax(), axis=0)

    # ind = index number in dataframe that had the max differences
    ind = stats.mode(max_df)[0][0]

    df.iloc[ind-1:ind] = np.NaN
    df_processed = df.apply(lambda col: col.interpolate(), axis=0)
    return df_processed


def apply_preprocessing_steps(df: pd.DataFrame, sample: str, player_metrics: pd.DataFrame):

    df_processed = df.copy()
    df_processed = zeros_to_nans(df_processed)
    df_processed = apply_interpolation(df_processed)


    trimmed_df = cut_out_noise_at_beginning_of_clips(df_processed)


    row_index = player_metrics.index[player_metrics['code'] == sample]
    column_index = '40_time'
    required_frames = int(round(player_metrics.loc[row_index,column_index]*30))


    if len(trimmed_df) >= required_frames:
        trimmed_df = trimmed_df.tail(required_frames)
        trimmed_df = remove_high_frequency_noise_at_single_index(trimmed_df)
        for i in range(3):
            trimmed_df = remove_high_frequency_noise_at_single_index(trimmed_df)
        trimmed_df = remove_high_frequency_noise_with_rolling_window_function(trimmed_df)

        return(trimmed_df)
    else:
        df_processed = df_processed.tail(required_frames)
        for i in range(10):
            df_processed = remove_high_frequency_noise_at_single_index(df_processed)
        df_processed = remove_high_frequency_noise_with_rolling_window_function(df_processed)

        return(df_processed)




keywords_dict = {
       0 : 'NOSE',  1 : 'NECK',  2 : 'RSHO',  3 : 'RELB',  4 : 'RWRI',
       5 : 'LSHO',  6 : 'LELB',  7 : 'LWRI',  8 : 'MHIP',  9 : 'RHIP',
      10 : 'RKNE', 11 : 'RANK', 12 : 'LHIP', 13 : 'LKNE', 14 : 'LANK',
      15 : 'REYE', 16 : 'LEYE', 17 : 'REAR', 18 : 'LEAR', 19 : 'LBTO',
      20 : 'LSTO', 21 : 'LHEL', 22 : 'RBTO', 23 : 'RSTO', 24 : 'RHEL'
      }

def save_plot_as_array_of_subplots(df, plot_name, save_path):
    """
    Saves plot in path, no return type
    Serves as a quick view of what the csv data looks like
    """
    fig, axs = plt.subplots(5, 5, figsize=(25, 25), constrained_layout=True)

    for ax, val in zip(axs.flat, keywords_dict.values()):

        ax.set_title(f'{val}')
        ax.set_xlabel('Time (%)', fontsize=10)
        ax.set_ylabel(f'{val}-Position', fontsize=10)

        ax.plot(df[f'{val}_X'], label=f'{val}_X')
        ax.plot(df[f'{val}_Y'], label=f'{val}_Y')

        ax.legend()
        ax.margins(x=0.01)
        
        ax.xaxis.set_major_locator(ticker.MultipleLocator(len(df)/5))
        ax.xaxis.set_minor_locator(ticker.MultipleLocator(len(df)/20))
        ax.xaxis.set_major_formatter(ticker.PercentFormatter(xmax=len(df)))
    
    fig.suptitle(plot_name, fontsize=25)
    plt.savefig(save_path)
    plt.close(fig)

# %% [markdown]
# ### Configure Save Paths

# %%
PROJ_SAVE_ROOT = os.path.join('/content/gdrive/MyDrive/ColabNotebooks/BiomechanicsAnalysis/___40_YARD_DASH/data/processed')
positions_list = os.listdir(PROJ_SAVE_ROOT)


player_metrics_file_path = '/content/gdrive/MyDrive/ColabNotebooks/BiomechanicsAnalysis/___40_YARD_DASH/data/40_yard_player_metrics.csv'
player_metrics = pd.read_csv(player_metrics_file_path, usecols=['code','40_time'])

for position_folder in positions_list:
    position_samples =  os.listdir(os.path.join(PROJ_SAVE_ROOT, position_folder))

    print(position_folder)
    for sample in position_samples:

        print(f'\t{sample}')

        # Define paths
        sample_csv_path = os.path.join(PROJ_SAVE_ROOT, position_folder, sample, f'{sample}.csv')
        raw_plot_path = os.path.join(PROJ_SAVE_ROOT, position_folder, sample, f'{sample}_plot_raw.png')

        processed_data_path = os.path.join(PROJ_SAVE_ROOT, position_folder, sample, f'{sample}_data_processed.csv')
        processed_plot_path = os.path.join(PROJ_SAVE_ROOT, position_folder, sample, f'{sample}_plot_processed.png')

        # Apply processing steps
        df = pd.read_csv(sample_csv_path, index_col=0)
        df_processed = apply_preprocessing_steps(df, sample, player_metrics)

        #Save data
        save_plot_as_array_of_subplots(df, sample, raw_plot_path)
        print(f'\t\t{sample:20} raw plot saved')

        df_processed.to_csv(processed_data_path)  
        print(f'\t\t{sample:20} processed data saved')

        save_plot_as_array_of_subplots(df_processed, sample, processed_plot_path)
        print(f'\t\t{sample:20} processed plot saved')
# Out:
# defensive_back
# 	defensive_back_01
# 		defensive_back_01    raw plot saved
# 		defensive_back_01    processed data saved
# 		defensive_back_01    processed plot saved
# 	defensive_back_02
# 		defensive_back_02    raw plot saved
# 		defensive_back_02    processed data saved
# 		defensive_back_02    processed plot saved
# 	defensive_back_03
# 		defensive_back_03    raw plot saved
# 		defensive_back_03    processed data saved
# 		defensive_back_03    processed plot saved
# 	defensive_back_04
# 		defensive_back_04    raw plot saved
# 		defensive_back_04    processed data saved
# 		defensive_back_04    processed plot saved
# 	defensive_back_05
# 		defensive_back_05    raw plot saved
# 		defensive_back_05    processed data saved
# 		defensive_back_05    processed plot saved
# 	defensive_back_06
# 		defensive_back_06    raw plot saved
# 		defensive_back_06    processed data saved
# 		defensive_back_06    processed plot saved
# 	defensive_back_07
# 		defensive_back_07    raw plot saved
# 		defensive_back_07    processed data saved
# 		defensive_back_07    processed plot saved
# 	defensive_back_08
# 		defensive_back_08    raw plot saved
# 		defensive_back_08    processed data saved
# 		defensive_back_08    processed plot saved
# 	defensive_back_09
# 		defensive_back_09    raw plot saved
# 		defensive_back_09    processed data saved
# 		defensive_back_09    processed plot saved
# 	defensive_back_10
# 		defensive_back_10    raw plot saved
# 		defensive_back_10    processed data saved
# 		defensive_back_10    processed plot saved
# 	defensive_back_11
# 		defensive_back_11    raw plot saved
# 		defensive_back_11    processed data saved
# 		defensive_back_11    processed plot saved
# 	defensive_back_12
# 		defensive_back_12    raw plot saved
# 		defensive_back_12    processed data saved
# 		defensive_back_12    processed plot saved
# 	defensive_back_13
# 		defensive_back_13    raw plot saved
# 		defensive_back_13    processed data saved
# 		defensive_back_13    processed plot saved
# 	defensive_back_14
# 		defensive_back_14    raw plot saved
# 		defensive_back_14    processed data saved
# 		defensive_back_14    processed plot saved
# 	defensive_back_15
# 		defensive_back_15    raw plot saved
# 		defensive_back_15    processed data saved
# 		defensive_back_15    processed plot saved
# 	defensive_back_16
# 		defensive_back_16    raw plot saved
# 		defensive_back_16    processed data saved
# 		defensive_back_16    processed plot saved
# 	defensive_back_17
# 		defensive_back_17    raw plot saved
# 		defensive_back_17    processed data saved
# 		defensive_back_17    processed plot saved
# 	defensive_back_18
# 		defensive_back_18    raw plot saved
# 		defensive_back_18    processed data saved
# 		defensive_back_18    processed plot saved
# 	defensive_back_19
# 		defensive_back_19    raw plot saved
# 		defensive_back_19    processed data saved
# 		defensive_back_19    processed plot saved
# 	defensive_back_20
# 		defensive_back_20    raw plot saved
# 		defensive_back_20    processed data saved
# 		defensive_back_20    processed plot saved
# 	defensive_back_21
# 		defensive_back_21    raw plot saved
# 		defensive_back_21    processed data saved
# 		defensive_back_21    processed plot saved
# 	defensive_back_22
# 		defensive_back_22    raw plot saved
# 		defensive_back_22    processed data saved
# 		defensive_back_22    processed plot saved
# 	defensive_back_23
# 		defensive_back_23    raw plot saved
# 		defensive_back_23    processed data saved
# 		defensive_back_23    processed plot saved
# 	defensive_back_24
# 		defensive_back_24    raw plot saved
# 		defensive_back_24    processed data saved
# 		defensive_back_24    processed plot saved
# 	defensive_back_25
# 		defensive_back_25    raw plot saved
# 		defensive_back_25    processed data saved
# 		defensive_back_25    processed plot saved
# defensive_line
# 	defensive_line_01
# 		defensive_line_01    raw plot saved
# 		defensive_line_01    processed data saved
# 		defensive_line_01    processed plot saved
# 	defensive_line_02
# 		defensive_line_02    raw plot saved
# 		defensive_line_02    processed data saved
# 		defensive_line_02    processed plot saved
# 	defensive_line_03
# 		defensive_line_03    raw plot saved
# 		defensive_line_03    processed data saved
# 		defensive_line_03    processed plot saved
# 	defensive_line_04
# 		defensive_line_04    raw plot saved
# 		defensive_line_04    processed data saved
# 		defensive_line_04    processed plot saved
# 	defensive_line_05
# 		defensive_line_05    raw plot saved
# 		defensive_line_05    processed data saved
# 		defensive_line_05    processed plot saved
# 	defensive_line_06
# 		defensive_line_06    raw plot saved
# 		defensive_line_06    processed data saved
# 		defensive_line_06    processed plot saved
# 	defensive_line_08
# 		defensive_line_08    raw plot saved
# 		defensive_line_08    processed data saved
# 		defensive_line_08    processed plot saved
# 	defensive_line_09
# 		defensive_line_09    raw plot saved
# 		defensive_line_09    processed data saved
# 		defensive_line_09    processed plot saved
# 	defensive_line_10
# 		defensive_line_10    raw plot saved
# 		defensive_line_10    processed data saved
# 		defensive_line_10    processed plot saved
# 	defensive_line_11
# 		defensive_line_11    raw plot saved
# 		defensive_line_11    processed data saved
# 		defensive_line_11    processed plot saved
# 	defensive_line_12
# 		defensive_line_12    raw plot saved
# 		defensive_line_12    processed data saved
# 		defensive_line_12    processed plot saved
# 	defensive_line_07
# 		defensive_line_07    raw plot saved
# 		defensive_line_07    processed data saved
# 		defensive_line_07    processed plot saved
# 	defensive_line_13
# 		defensive_line_13    raw plot saved
# 		defensive_line_13    processed data saved
# 		defensive_line_13    processed plot saved
# 	defensive_line_14
# 		defensive_line_14    raw plot saved
# 		defensive_line_14    processed data saved
# 		defensive_line_14    processed plot saved
# 	defensive_line_15
# 		defensive_line_15    raw plot saved
# 		defensive_line_15    processed data saved
# 		defensive_line_15    processed plot saved
# 	defensive_line_16
# 		defensive_line_16    raw plot saved
# 		defensive_line_16    processed data saved
# 		defensive_line_16    processed plot saved
# 	defensive_line_17
# 		defensive_line_17    raw plot saved
# 		defensive_line_17    processed data saved
# 		defensive_line_17    processed plot saved
# 	defensive_line_18
# 		defensive_line_18    raw plot saved
# 		defensive_line_18    processed data saved
# 		defensive_line_18    processed plot saved
# 	defensive_line_19
# 		defensive_line_19    raw plot saved
# 		defensive_line_19    processed data saved
# 		defensive_line_19    processed plot saved
# 	defensive_line_20
# 		defensive_line_20    raw plot saved
# 		defensive_line_20    processed data saved
# 		defensive_line_20    processed plot saved
# 	defensive_line_21
# 		defensive_line_21    raw plot saved
# 		defensive_line_21    processed data saved
# 		defensive_line_21    processed plot saved
# 	defensive_line_22
# 		defensive_line_22    raw plot saved
# 		defensive_line_22    processed data saved
# 		defensive_line_22    processed plot saved
# 	defensive_line_23
# 		defensive_line_23    raw plot saved
# 		defensive_line_23    processed data saved
# 		defensive_line_23    processed plot saved
# 	defensive_line_24
# 		defensive_line_24    raw plot saved
# 		defensive_line_24    processed data saved
# 		defensive_line_24    processed plot saved
# 	defensive_line_25
# 		defensive_line_25    raw plot saved
# 		defensive_line_25    processed data saved
# 		defensive_line_25    processed plot saved
# offensive_line
# 	offensive_line_01
# 		offensive_line_01    raw plot saved
# 		offensive_line_01    processed data saved
# 		offensive_line_01    processed plot saved
# 	offensive_line_02
# 		offensive_line_02    raw plot saved
# 		offensive_line_02    processed data saved
# 		offensive_line_02    processed plot saved
# 	offensive_line_03
# 		offensive_line_03    raw plot saved
# 		offensive_line_03    processed data saved
# 		offensive_line_03    processed plot saved
# 	offensive_line_04
# 		offensive_line_04    raw plot saved
# 		offensive_line_04    processed data saved
# 		offensive_line_04    processed plot saved
# 	offensive_line_05
# 		offensive_line_05    raw plot saved
# 		offensive_line_05    processed data saved
# 		offensive_line_05    processed plot saved
# 	offensive_line_06
# 		offensive_line_06    raw plot saved
# 		offensive_line_06    processed data saved
# 		offensive_line_06    processed plot saved
# 	offensive_line_07
# 		offensive_line_07    raw plot saved
# 		offensive_line_07    processed data saved
# 		offensive_line_07    processed plot saved
# 	offensive_line_08
# 		offensive_line_08    raw plot saved
# 		offensive_line_08    processed data saved
# 		offensive_line_08    processed plot saved
# 	offensive_line_09
# 		offensive_line_09    raw plot saved
# 		offensive_line_09    processed data saved
# 		offensive_line_09    processed plot saved
# 	offensive_line_10
# 		offensive_line_10    raw plot saved
# 		offensive_line_10    processed data saved
# 		offensive_line_10    processed plot saved
# 	offensive_line_11
# 		offensive_line_11    raw plot saved
# 		offensive_line_11    processed data saved
# 		offensive_line_11    processed plot saved
# 	offensive_line_12
# 		offensive_line_12    raw plot saved
# 		offensive_line_12    processed data saved
# 		offensive_line_12    processed plot saved
# 	offensive_line_13
# 		offensive_line_13    raw plot saved
# 		offensive_line_13    processed data saved
# 		offensive_line_13    processed plot saved
# 	offensive_line_14
# 		offensive_line_14    raw plot saved
# 		offensive_line_14    processed data saved
# 		offensive_line_14    processed plot saved
# 	offensive_line_15
# 		offensive_line_15    raw plot saved
# 		offensive_line_15    processed data saved
# 		offensive_line_15    processed plot saved
# 	offensive_line_16
# 		offensive_line_16    raw plot saved
# 		offensive_line_16    processed data saved
# 		offensive_line_16    processed plot saved
# 	offensive_line_17
# 		offensive_line_17    raw plot saved
# 		offensive_line_17    processed data saved
# 		offensive_line_17    processed plot saved
# 	offensive_line_18
# 		offensive_line_18    raw plot saved
# 		offensive_line_18    processed data saved
# 		offensive_line_18    processed plot saved
# 	offensive_line_19
# 		offensive_line_19    raw plot saved
# 		offensive_line_19    processed data saved
# 		offensive_line_19    processed plot saved
# 	offensive_line_20
# 		offensive_line_20    raw plot saved
# 		offensive_line_20    processed data saved
# 		offensive_line_20    processed plot saved
# 	offensive_line_21
# 		offensive_line_21    raw plot saved
# 		offensive_line_21    processed data saved
# 		offensive_line_21    processed plot saved
# 	offensive_line_22
# 		offensive_line_22    raw plot saved
# 		offensive_line_22    processed data saved
# 		offensive_line_22    processed plot saved
# 	offensive_line_23
# 		offensive_line_23    raw plot saved
# 		offensive_line_23    processed data saved
# 		offensive_line_23    processed plot saved
# 	offensive_line_24
# 		offensive_line_24    raw plot saved
# 		offensive_line_24    processed data saved
# 		offensive_line_24    processed plot saved
# 	offensive_line_25
# 		offensive_line_25    raw plot saved
# 		offensive_line_25    processed data saved
# 		offensive_line_25    processed plot saved
# quarterbacks
# 	quarterbacks_01
# 		quarterbacks_01      raw plot saved
# 		quarterbacks_01      processed data saved
# 		quarterbacks_01      processed plot saved
# 	quarterbacks_02
# 		quarterbacks_02      raw plot saved
# 		quarterbacks_02      processed data saved
# 		quarterbacks_02      processed plot saved
# 	quarterbacks_03
# 		quarterbacks_03      raw plot saved
# 		quarterbacks_03      processed data saved
# 		quarterbacks_03      processed plot saved
# 	quarterbacks_04
# 		quarterbacks_04      raw plot saved
# 		quarterbacks_04      processed data saved
# 		quarterbacks_04      processed plot saved
# 	quarterbacks_05
# 		quarterbacks_05      raw plot saved
# 		quarterbacks_05      processed data saved
# 		quarterbacks_05      processed plot saved
# 	quarterbacks_06
# 		quarterbacks_06      raw plot saved
# 		quarterbacks_06      processed data saved
# 		quarterbacks_06      processed plot saved
# 	quarterbacks_07
# 		quarterbacks_07      raw plot saved
# 		quarterbacks_07      processed data saved
# 		quarterbacks_07      processed plot saved
# 	quarterbacks_08
# 		quarterbacks_08      raw plot saved
# 		quarterbacks_08      processed data saved
# 		quarterbacks_08      processed plot saved
# 	quarterbacks_09
# 		quarterbacks_09      raw plot saved
# 		quarterbacks_09      processed data saved
# 		quarterbacks_09      processed plot saved
# 	quarterbacks_10
# 		quarterbacks_10      raw plot saved
# 		quarterbacks_10      processed data saved
# 		quarterbacks_10      processed plot saved
# 	quarterbacks_11
# 		quarterbacks_11      raw plot saved
# 		quarterbacks_11      processed data saved
# 		quarterbacks_11      processed plot saved
# 	quarterbacks_12
# 		quarterbacks_12      raw plot saved
# 		quarterbacks_12      processed data saved
# 		quarterbacks_12      processed plot saved
# 	quarterbacks_13
# 		quarterbacks_13      raw plot saved
# 		quarterbacks_13      processed data saved
# 		quarterbacks_13      processed plot saved
# 	quarterbacks_14
# 		quarterbacks_14      raw plot saved
# 		quarterbacks_14      processed data saved
# 		quarterbacks_14      processed plot saved
# 	quarterbacks_15
# 		quarterbacks_15      raw plot saved
# 		quarterbacks_15      processed data saved
# 		quarterbacks_15      processed plot saved
# 	quarterbacks_16
# 		quarterbacks_16      raw plot saved
# 		quarterbacks_16      processed data saved
# 		quarterbacks_16      processed plot saved
# 	quarterbacks_17
# 		quarterbacks_17      raw plot saved
# 		quarterbacks_17      processed data saved
# 		quarterbacks_17      processed plot saved
# 	quarterbacks_18
# 		quarterbacks_18      raw plot saved
# 		quarterbacks_18      processed data saved
# 		quarterbacks_18      processed plot saved
# 	quarterbacks_19
# 		quarterbacks_19      raw plot saved
# 		quarterbacks_19      processed data saved
# 		quarterbacks_19      processed plot saved
# 	quarterbacks_20
# 		quarterbacks_20      raw plot saved
# 		quarterbacks_20      processed data saved
# 		quarterbacks_20      processed plot saved
# 	quarterbacks_21
# 		quarterbacks_21      raw plot saved
# 		quarterbacks_21      processed data saved
# 		quarterbacks_21      processed plot saved
# 	quarterbacks_22
# 		quarterbacks_22      raw plot saved
# 		quarterbacks_22      processed data saved
# 		quarterbacks_22      processed plot saved
# 	quarterbacks_23
# 		quarterbacks_23      raw plot saved
# 		quarterbacks_23      processed data saved
# 		quarterbacks_23      processed plot saved
# 	quarterbacks_24
# 		quarterbacks_24      raw plot saved
# 		quarterbacks_24      processed data saved
# 		quarterbacks_24      processed plot saved
# 	quarterbacks_25
# 		quarterbacks_25      raw plot saved
# 		quarterbacks_25      processed data saved
# 		quarterbacks_25      processed plot saved
# running_backs
# 	running_backs_01
# 		running_backs_01     raw plot saved
# 		running_backs_01     processed data saved
# 		running_backs_01     processed plot saved
# 	running_backs_02
# 		running_backs_02     raw plot saved
# 		running_backs_02     processed data saved
# 		running_backs_02     processed plot saved
# 	running_backs_03
# 		running_backs_03     raw plot saved
# 		running_backs_03     processed data saved
# 		running_backs_03     processed plot saved
# 	running_backs_04
# 		running_backs_04     raw plot saved
# 		running_backs_04     processed data saved
# 		running_backs_04     processed plot saved
# 	running_backs_05
# 		running_backs_05     raw plot saved
# 		running_backs_05     processed data saved
# 		running_backs_05     processed plot saved
# 	running_backs_06
# 		running_backs_06     raw plot saved
# 		running_backs_06     processed data saved
# 		running_backs_06     processed plot saved
# 	running_backs_07
# 		running_backs_07     raw plot saved
# 		running_backs_07     processed data saved
# 		running_backs_07     processed plot saved
# 	running_backs_08
# 		running_backs_08     raw plot saved
# 		running_backs_08     processed data saved
# 		running_backs_08     processed plot saved
# 	running_backs_09
# 		running_backs_09     raw plot saved
# 		running_backs_09     processed data saved
# 		running_backs_09     processed plot saved
# 	running_backs_10
# 		running_backs_10     raw plot saved
# 		running_backs_10     processed data saved
# 		running_backs_10     processed plot saved
# 	running_backs_11
# 		running_backs_11     raw plot saved
# 		running_backs_11     processed data saved
# 		running_backs_11     processed plot saved
# 	running_backs_12
# 		running_backs_12     raw plot saved
# 		running_backs_12     processed data saved
# 		running_backs_12     processed plot saved
# 	running_backs_13
# 		running_backs_13     raw plot saved
# 		running_backs_13     processed data saved
# 		running_backs_13     processed plot saved
# 	running_backs_14
# 		running_backs_14     raw plot saved
# 		running_backs_14     processed data saved
# 		running_backs_14     processed plot saved
# 	running_backs_15
# 		running_backs_15     raw plot saved
# 		running_backs_15     processed data saved
# 		running_backs_15     processed plot saved
# 	running_backs_16
# 		running_backs_16     raw plot saved
# 		running_backs_16     processed data saved
# 		running_backs_16     processed plot saved
# 	running_backs_17
# 		running_backs_17     raw plot saved
# 		running_backs_17     processed data saved
# 		running_backs_17     processed plot saved
# 	running_backs_18
# 		running_backs_18     raw plot saved
# 		running_backs_18     processed data saved
# 		running_backs_18     processed plot saved
# 	running_backs_19
# 		running_backs_19     raw plot saved
# 		running_backs_19     processed data saved
# 		running_backs_19     processed plot saved
# 	running_backs_20
# 		running_backs_20     raw plot saved
# 		running_backs_20     processed data saved
# 		running_backs_20     processed plot saved
# 	running_backs_21
# 		running_backs_21     raw plot saved
# 		running_backs_21     processed data saved
# 		running_backs_21     processed plot saved
# 	running_backs_22
# 		running_backs_22     raw plot saved
# 		running_backs_22     processed data saved
# 		running_backs_22     processed plot saved
# 	running_backs_23
# 		running_backs_23     raw plot saved
# 		running_backs_23     processed data saved
# 		running_backs_23     processed plot saved
# 	running_backs_24
# 		running_backs_24     raw plot saved
# 		running_backs_24     processed data saved
# 		running_backs_24     processed plot saved
# 	running_backs_25
# 		running_backs_25     raw plot saved
# 		running_backs_25     processed data saved
# 		running_backs_25     processed plot saved
# wide_receivers
# 	wide_receivers_01
# 		wide_receivers_01    raw plot saved
# 		wide_receivers_01    processed data saved
# 		wide_receivers_01    processed plot saved
# 	wide_receivers_02
# 		wide_receivers_02    raw plot saved
# 		wide_receivers_02    processed data saved
# 		wide_receivers_02    processed plot saved
# 	wide_receivers_03
# 		wide_receivers_03    raw plot saved
# 		wide_receivers_03    processed data saved
# 		wide_receivers_03    processed plot saved
# 	wide_receivers_04
# 		wide_receivers_04    raw plot saved
# 		wide_receivers_04    processed data saved
# 		wide_receivers_04    processed plot saved
# 	wide_receivers_05
# 		wide_receivers_05    raw plot saved
# 		wide_receivers_05    processed data saved
# 		wide_receivers_05    processed plot saved
# 	wide_receivers_06
# 		wide_receivers_06    raw plot saved
# 		wide_receivers_06    processed data saved
# 		wide_receivers_06    processed plot saved
# 	wide_receivers_07
# 		wide_receivers_07    raw plot saved
# 		wide_receivers_07    processed data saved
# 		wide_receivers_07    processed plot saved
# 	wide_receivers_08
# 		wide_receivers_08    raw plot saved
# 		wide_receivers_08    processed data saved
# 		wide_receivers_08    processed plot saved
# 	wide_receivers_09
# 		wide_receivers_09    raw plot saved
# 		wide_receivers_09    processed data saved
# 		wide_receivers_09    processed plot saved
# 	wide_receivers_10
# 		wide_receivers_10    raw plot saved
# 		wide_receivers_10    processed data saved
# 		wide_receivers_10    processed plot saved
# 	wide_receivers_11
# 		wide_receivers_11    raw plot saved
# 		wide_receivers_11    processed data saved
# 		wide_receivers_11    processed plot saved
# 	wide_receivers_12
# 		wide_receivers_12    raw plot saved
# 		wide_receivers_12    processed data saved
# 		wide_receivers_12    processed plot saved
# 	wide_receivers_13
# 		wide_receivers_13    raw plot saved
# 		wide_receivers_13    processed data saved
# 		wide_receivers_13    processed plot saved
# 	wide_receivers_14
# 		wide_receivers_14    raw plot saved
# 		wide_receivers_14    processed data saved
# 		wide_receivers_14    processed plot saved
# 	wide_receivers_15
# 		wide_receivers_15    raw plot saved
# 		wide_receivers_15    processed data saved
# 		wide_receivers_15    processed plot saved
# 	wide_receivers_16
# 		wide_receivers_16    raw plot saved
# 		wide_receivers_16    processed data saved
# 		wide_receivers_16    processed plot saved
# 	wide_receivers_17
# 		wide_receivers_17    raw plot saved
# 		wide_receivers_17    processed data saved
# 		wide_receivers_17    processed plot saved
# 	wide_receivers_18
# 		wide_receivers_18    raw plot saved
# 		wide_receivers_18    processed data saved
# 		wide_receivers_18    processed plot saved
# 	wide_receivers_19
# 		wide_receivers_19    raw plot saved
# 		wide_receivers_19    processed data saved
# 		wide_receivers_19    processed plot saved
# 	wide_receivers_20
# 		wide_receivers_20    raw plot saved
# 		wide_receivers_20    processed data saved
# 		wide_receivers_20    processed plot saved
# 	wide_receivers_21
# 		wide_receivers_21    raw plot saved
# 		wide_receivers_21    processed data saved
# 		wide_receivers_21    processed plot saved
# 	wide_receivers_22
# 		wide_receivers_22    raw plot saved
# 		wide_receivers_22    processed data saved
# 		wide_receivers_22    processed plot saved
# 	wide_receivers_23
# 		wide_receivers_23    raw plot saved
# 		wide_receivers_23    processed data saved
# 		wide_receivers_23    processed plot saved
# 	wide_receivers_24
# 		wide_receivers_24    raw plot saved
# 		wide_receivers_24    processed data saved
# 		wide_receivers_24    processed plot saved
# 	wide_receivers_25
# 		wide_receivers_25    raw plot saved
# 		wide_receivers_25    processed data saved
# 		wide_receivers_25    processed plot saved
